# %%
import matplotlib.pyplot as plt

from src.data_loader import load_stock_data
from src.returns import compute_log_returns
from src.volatility import rolling_volatility
from src.statistics import normality_test, stationarity_test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 from src.data_loader import load_stock_data
#       4 from src.returns import compute_log_returns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df = load_stock_data("NVIDIA-STOCK-PRICE/data/raw/NVIDIA_Stock_Price.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = load_stock_data("NVIDIA-STOCK-PRICE/data/raw/NVIDIA_Stock_Price.csv")
#
# NameError: name 'load_stock_data' is not defined
